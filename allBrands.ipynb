# %%
from bs4 import BeautifulSoup
import requests
import urllib.parse
from urllib.parse import urljoin
import time
import csv

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) '\
           'AppleWebKit/537.36 (KHTML, like Gecko) '\
           'Chrome/75.0.3770.80 Safari/537.36'}

# %%
def brands_links():
    
    url = 'https://www.leguidedesmontres.com/en/products-new'

    response = requests.get(url, headers=headers)

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the div with id "resultsBlk"
    results_div = soup.find('div', id='resultsBlk')

    # Extract links from all items
    relative_links = [item.a['href'] for item in results_div.find_all('div', class_='item')]

    # Extracting the links from the <li> elements and joining with the base URL
    base_url = 'https://www.leguidedesmontres.com'  # Replace with the actual base URL

    # Create complete URLs by concatenating with the base URL
    all_brands_links = [urllib.parse.urljoin(base_url, link) for link in relative_links]


    return all_brands_links

# %%
brandsLink = brands_links()

# %%
brandsLink
# Out:
# ['https://www.leguidedesmontres.com/en/products-new/a-lange-amp-sohne?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/audemars-piguet?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/brm?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/baume-et-mercier?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/bell-amp-ross?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/blancpain?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/boucheron?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/breguet?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/breitling?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/bulgari?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/cartier?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/chanel?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/chaumet?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/chopard?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/concord?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/corum?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/daniel-roth?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/ebel?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/fp-journe?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/franck-muller?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/girard-perregaux?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/glashutte-original?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/graham?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/hermes?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/hublot?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/iwc?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/jaeger-lecoultre?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/jaquet-droz?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/louis-vuitton?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/omega?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/panerai?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/parmigiani-fleurier?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/patek-philippe?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/pequignet?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/piaget?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/pierre-kunz?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/richard-mille?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/roger-dubuis?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/rolex?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/tag-heuer?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/tudor?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/ulysse-nardin?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/universal-geneve?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/vacheron-constantin?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947']

# %%
def products_links(brandsLink):
    
    for i in brandsLink:
        
        response = requests.get(i, headers=headers)

        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the div with id "resultsBlk"
        results_div = soup.find('div', id='brands-results-main')

        # Extract links from all items
        relative_links = [item.a['href'] for item in results_div.find_all('div', class_='item')]

        # Extracting the links from the <li> elements and joining with the base URL
        base_url = "https://www.leguidedesmontres.com"  # Replace with the actual base URL

        # Create complete URLs by concatenating with the base URL
        all_products_links = [urllib.parse.urljoin(base_url, link) for link in relative_links]

    return all_products_links

# %%
productLink = products_links(brandsLink)

# %%
productLink
# Out:
# ['https://www.leguidedesmontres.com/en/products-new/zenith/2653/03215040021m2150?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2652/03215040069m2150?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2627/18215040021c709?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2625/22215040075c709?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2593/452210880409c630?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2591/402210880495c631?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2588/652210880401c630?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2586/352210880401c631?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2515/182210880401c631?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2596/652220880801c630?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2731/03202067001c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2723/18202067001c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2722/03202067076c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2512/03202067021m2020?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2501/51202067001m2020?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2671/18211040002c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2670/22211040002c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2669/16211040002c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2668/03211540021c703?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2667/03211040021m2110?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2666/51211240001m2110?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2665/03211040075c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2664/03211040001m2110?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2663/51211240001c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2661/18211040001c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2660/03211040001c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2587/03211640051c700?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2721/18213068202c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2720/03213063202c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2680/03213068222c493?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2674/03214069102c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2673/22214069102c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2672/18214069102c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2679/03212068522c493?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2678/03212068502c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2677/16212068502c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2676/65212068591c493?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2675/18212068502c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2659/032070405422c708?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2658/032070405402c711?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2656/182070405402c711?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2590/032051403551c715?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2589/03204140051c496?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2650/03204040021m2040?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2649/03204040022c496?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2648/18204040001c494?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2654/03215040051m2150?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2651/03215040069c713?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2630/03215040051c705?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2629/03215040021c706?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2623/22215140081c709?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2631/032160404701c713?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2628/032080402101c494?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2626/032080402121m2040?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2624/402082402191c496?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2620/182080402101c494?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2618/752050402621r530?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2616/512050402601c713?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2612/782050402691r530?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2610/032050402691c630?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2647/24206240527c707?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2646/45206340521c714?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2645/45206240521c714?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2644/45206040529c714?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2643/85206040523c714?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2642/86206040523c714?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2641/03206040521m2060?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2640/03206040521c714?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2639/24206040521c707?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2638/242061405767c707?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2637/032060405769c714?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2636/032043405201m2040?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2635/032043405201c496?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2634/402041405291c496?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2633/032041405269m2040?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2632/032041405269c496?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2733/652050403591c714?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2606/032050403501c713?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2605/032050403521c714?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2600/452050403509c714?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2598/182050403501c713?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2619/16231069281c706?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2617/16231069202c706?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2611/18231069202c709?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2609/18231069281c709?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2513/03201268151c503?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2604/03196567091c591?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2655/032117400223c704?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2514/03206240507m2060?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2607/1850002572pc01c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2603/03201068121c493?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2602/03201068191c493?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2601/03201068101c493?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2599/03201068111c493?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2597/18201068111c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2594/18201068121c493?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2592/18201068101c498?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2622/45231069281c717?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2621/16231069251c705?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2615/18231069275c709?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2613/22231069275c709?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947',
#  'https://www.leguidedesmontres.com/en/products-new/zenith/2608/22231069281c709?PHPSESSID=fb8cdb7e84663a6925d60e2f467a9947']

# %%
imgUrls=[];productName=[];sku=[];Mouvement=[];Functions=[];Box=[];Bracelet=[]
Remarks=[];Price=[];productUrls=[]
def Product_details(links):
    c = 0
    for i in links:
        print(i)
        response = requests.get(i, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the div with id "product-details-info"
        product_details_info = soup.find('div', id='product-details-info')

        try:
            base_url = "https://www.leguidedesmontres.com"

            # Extract image URL
            relative_img_url = product_details_info.find('img', id='otherview-full-image')['src']

            # Create complete image URL by concatenating with the base URL
            img_url = urllib.parse.urljoin(base_url, relative_img_url)
            img_url = img_url.replace(" ", "")
            imgUrls.append(img_url)
            print(imgUrls)
        except:
            imgUrls.append('')

        productUrls.append(i)

        # Find the h2 element
        h2_element = soup.find('h2')

        try:
            # Extract product name
            product_name = h2_element.contents[0].strip()
            productName.append(product_name)
            print(productName)
        except:
            productName.append('')
        
        try:
            # Extract SKU number
            sku_number = h2_element.span.get_text(strip=True)
            sku.append(sku_number)
            print(sku)
        except:
            sku.append('')
        
        # Find the div with id "product-specs"
        product_specs = soup.find('div', id='product-specs')
        # print(product_specs)
        
        try:
            # Extract movement
            mouvement = product_specs.find('p', class_='detail-label', string='Mouvement').find_next('p', class_='detail-info').get_text(strip=True)
            Mouvement.append(mouvement)
            print(Mouvement)
        except:
            Mouvement.append('')

        try:
            # Extract function
            functions = product_specs.find('p', class_='detail-label', string='Functions').find_next('p', class_='detail-info').get_text(strip=True)
            Functions.append(functions)
            print(Functions)
        except:
            Functions.append('')

        try:
            # Extract box
            box = product_specs.find('p', class_='detail-label', string='Box').find_next('p', class_='detail-info').get_text(strip=True)
            Box.append(box)
            print(Box)
        except:
            Box.append('')

        try:
            # Extract bracelet
            bracelet = product_specs.find('p', class_='detail-label', string='Bracelet').find_next('p', class_='detail-info').get_text(strip=True)
            Bracelet.append(bracelet)
            print(Bracelet)
        except:
            Bracelet.append('')
        
        try:
            # Extract remarks
            remarks = product_specs.find('p', class_='detail-label', string='Remarks').find_next('p', class_='detail-info').get_text(strip=True)
            Remarks.append(remarks)
            print(Remarks)
        except:
            Remarks.append('')
        
        # Extract Price
        price_detail = product_details_info.find('div', class_='price-detail')

        try:
            # Extract price
            price = price_detail.find('p', class_='detail-info').get_text(strip=True)
            Price.append(price)
            print(Price)
        except:
            Price.append('')

        break


    return True

# %%
p = ['https://www.leguidedesmontres.com/en/products-new/a-lange-amp-sohne/1003/233021#']
# Product_details(productLink)
Product_details(p)
# Out:
# https://www.leguidedesmontres.com/en/products-new/a-lange-amp-sohne/1003/233021#
# ['https://www.leguidedesmontres.com/_files/references/images/1003_1047_a._lange_amp_sohne__233.021.jpg']
# ['A. Lange & Söhne']
# ['1815 233.021']
# ['Manual winding']
# ['Hour, minute, second']
# ['Gold']
# ['Croco']
# ['ø 40,0mm']
# ['18,400.00 €']
# True

# %%
import pandas as pd

data = {
    'Image Urls': [' '.join(img_urls) for img_urls in imgUrls],
    'SKU': sku,
    'Product Name': productName,
    'Mouvement': Mouvement,
    'Functions': Functions,
    'Box': Box,
    'Bracelet': Bracelet,
    'Remarks': Remarks,
    'Price': Price,
    'Product Url': productUrls
}

df = pd.DataFrame(data)

# Writing to Excel file
excel_file_path = 'output1.xlsx'
df.to_excel(excel_file_path, index=False)
